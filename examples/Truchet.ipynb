# %%
from truchet_viewer.smith import smith
smith(tilew=40, seed=4, grid=False)

# %%
from truchet_viewer.carlson import carlson_tiles
from truchet_viewer.tiler import show_tiles
show_tiles(carlson_tiles, width=600, sort=False, frac=.5)

# %%
from truchet_viewer import multiscale_truchet

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=600, tilew=100, nlayers=3, chance=.5, seed=11, grid=True)

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=400, tilew=20, nlayers=1, chance=.5, format="png", seed=11)

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=400, tilew=20, nlayers=2, chance=.2, format="png", seed=11)
