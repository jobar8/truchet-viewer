# %%
from truchet_viewer.carlson import carlson_tiles, carlson_demo
from truchet_viewer.tiler import show_tiles, multiscale_truchet
show_tiles(carlson_demo, with_value=True, with_name=True, frac=.5)

# %%
from truchet_viewer.tiler import value_chart
value_chart(carlson_demo, inverted=True)

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=600, tilew=100, nlayers=4, chance=.5, grid=0, seed=128)

# %%
multiscale_truchet(tiles=carlson_tiles, 
    width=2160, height=3840, tilew=240, nlayers=3, chance=.4, bg="#335495", fg="#243b6a", 
    format="png", output="~/wallpaper/tru.png",
)
# Out:
# <b><i>Wrote to /home/joseph/wallpaper/tru.png</i></b>

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=100, tilew=20, nlayers=3, chance=.5, format="png")

# %%
multiscale_truchet(tiles=carlson_tiles, width=800, height=800, tilew=20, nlayers=3, chance=.5, format="svg", output="~/wallpaper/carlson.svg")
# Out:
# <b><i>Wrote to /home/joseph/wallpaper/carlson.svg</i></b>

# %%
from truchet_viewer.helpers import make_bgfg
multiscale_truchet(tiles=carlson_tiles, width=800, height=400, tilew=100, nlayers=4, chance=.4, grid=0, seed=12, **make_bgfg(.35, (.52, .4), .3))
